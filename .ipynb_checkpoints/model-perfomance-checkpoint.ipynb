# %%
import os
import subprocess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns # I love this package!
sns.set_style('white')

import torch

# %% [markdown]
# ### Loss Trend Check

# %%
# load check point
model_path = 'output/checkpoint.pth.tar'
checkpoint = torch.load('output/checkpoint.pth.tar')
print("ch",checkpoint)
loss_history_train = checkpoint['loss_history_train']
loss_history_val = checkpoint['loss_history_val']
loss_train = [np.mean(l) for l in loss_history_train]
loss_val = [np.mean(l) for l in loss_history_val]
plt.plot(loss_train, label = 'Train Loss')
plt.plot(loss_val, label = 'Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Trend')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-c1cb35efd9d9> in <module>
#       1 # load check point
#       2 model_path = 'output/checkpoint.pth.tar'
# ----> 3 checkpoint = torch.load(model_path)
#       4 loss_history_train = checkpoint['loss_history_train']
#       5 loss_history_val = checkpoint['loss_history_val']
#
# ~/anaconda3/envs/pytorch14/lib/python3.8/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     525     with _open_file_like(f, 'rb') as opened_file:
#     526         if _is_zipfile(opened_file):
# --> 527             with _open_zipfile_reader(f) as opened_zipfile:
#     528                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     529         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# ~/anaconda3/envs/pytorch14/lib/python3.8/site-packages/torch/serialization.py in __init__(self, name_or_buffer)
#     222 class _open_zipfile_reader(_opener):
#     223     def __init__(self, name_or_buffer):
# --> 224         super(_open_zipfile_reader, self).__init__(torch._C.PyTorchFileReader(name_or_buffer))
#     225
#     226
#
# RuntimeError: version_ <= kMaxSupportedFileFormatVersion INTERNAL ASSERT FAILED at /opt/conda/conda-bld/pytorch_1579022027550/work/caffe2/serialize/inline_container.cc:132, please report a bug to PyTorch. Attempted to read a PyTorch file with version 3, but the maximum supported version for reading is 2. Your PyTorch installation may be too old. (init at /opt/conda/conda-bld/pytorch_1579022027550/work/caffe2/serialize/inline_container.cc:132)
# frame #0: c10::Error::Error(c10::SourceLocation, std::string const&) + 0x47 (0x7f25f3017627 in /home/pawat/anaconda3/envs/pytorch14/lib/python3.8/site-packages/torch/lib/libc10.so)
# frame #1: caffe2::serialize::PyTorchStreamReader::init() + 0x1f5b (0x7f25f7a889ab in /home/pawat/anaconda3/envs/pytorch14/lib/python3.8/site-packages/torch/lib/libtorch.so)
# frame #2: caffe2::serialize::PyTorchStreamReader::PyTorchStreamReader(std::string const&) + 0x64 (0x7f25f7a89bc4 in /home/pawat/anaconda3/envs/pytorch14/lib/python3.8/site-packages/torch/lib/libtorch.so)
# frame #3: <unknown function> + 0x6ce4b6 (0x7f26254d04b6 in /home/pawat/anaconda3/envs/pytorch14/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #4: <unknown function> + 0x28b8a7 (0x7f262508d8a7 in /home/pawat/anaconda3/envs/pytorch14/lib/python3.8/site-packages/torch/lib/libtorch_python.so)
# frame #5: PyCFunction_Call + 0x56 (0x558f08600f76 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #6: _PyObject_MakeTpCall + 0x22f (0x558f085be85f in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #7: <unknown function> + 0x18bfdc (0x558f0860cfdc in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #8: PyVectorcall_Call + 0x71 (0x558f085be041 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #9: <unknown function> + 0x18c92a (0x558f0860d92a in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #10: _PyObject_MakeTpCall + 0x1a4 (0x558f085be7d4 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #11: _PyEval_EvalFrameDefault + 0x4596 (0x558f08645f56 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #12: _PyEval_EvalCodeWithName + 0x659 (0x558f0860be19 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #13: _PyObject_FastCallDict + 0x20c (0x558f0860d48c in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #14: _PyObject_Call_Prepend + 0x63 (0x558f0860d733 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #15: <unknown function> + 0x18c8ca (0x558f0860d8ca in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #16: _PyObject_MakeTpCall + 0x1a4 (0x558f085be7d4 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #17: _PyEval_EvalFrameDefault + 0x475 (0x558f08641e35 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #18: _PyEval_EvalCodeWithName + 0x2d2 (0x558f0860ba92 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #19: _PyFunction_Vectorcall + 0x1e3 (0x558f0860c943 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #20: <unknown function> + 0x10077f (0x558f0858177f in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #21: _PyEval_EvalCodeWithName + 0x2d2 (0x558f0860ba92 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #22: PyEval_EvalCodeEx + 0x44 (0x558f0860c754 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #23: PyEval_EvalCode + 0x1c (0x558f0869aedc in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #24: <unknown function> + 0x24f083 (0x558f086d0083 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #25: <unknown function> + 0x140699 (0x558f085c1699 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #26: <unknown function> + 0xfeb84 (0x558f0857fb84 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #27: _PyGen_Send + 0x149 (0x558f08605dc9 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #28: _PyEval_EvalFrameDefault + 0x49a3 (0x558f08646363 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #29: _PyGen_Send + 0x149 (0x558f08605dc9 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #30: _PyEval_EvalFrameDefault + 0x49a3 (0x558f08646363 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #31: _PyGen_Send + 0x149 (0x558f08605dc9 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #32: <unknown function> + 0x1701cd (0x558f085f11cd in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #33: <unknown function> + 0x10075e (0x558f0858175e in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #34: _PyFunction_Vectorcall + 0x10b (0x558f0860c86b in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #35: <unknown function> + 0xfeb84 (0x558f0857fb84 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #36: _PyFunction_Vectorcall + 0x10b (0x558f0860c86b in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #37: <unknown function> + 0x10075e (0x558f0858175e in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #38: _PyEval_EvalCodeWithName + 0x2d2 (0x558f0860ba92 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #39: _PyFunction_Vectorcall + 0x1e3 (0x558f0860c943 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #40: <unknown function> + 0x18be79 (0x558f0860ce79 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #41: PyVectorcall_Call + 0x71 (0x558f085be041 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #42: _PyEval_EvalFrameDefault + 0x1fdb (0x558f0864399b in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #43: _PyEval_EvalCodeWithName + 0x659 (0x558f0860be19 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #44: <unknown function> + 0x18bd20 (0x558f0860cd20 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #45: <unknown function> + 0x10011a (0x558f0858111a in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #46: <unknown function> + 0x215056 (0x558f08696056 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #47: <unknown function> + 0x1847f3 (0x558f086057f3 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #48: <unknown function> + 0x140699 (0x558f085c1699 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #49: <unknown function> + 0x7df36 (0x558f084fef36 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #50: <unknown function> + 0x8af1b (0x558f0850bf1b in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #51: <unknown function> + 0x1409a0 (0x558f085c19a0 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #52: <unknown function> + 0xfeb84 (0x558f0857fb84 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #53: _PyEval_EvalCodeWithName + 0x659 (0x558f0860be19 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #54: _PyFunction_Vectorcall + 0x1e3 (0x558f0860c943 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #55: <unknown function> + 0x10075e (0x558f0858175e in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #56: <unknown function> + 0x215056 (0x558f08696056 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #57: <unknown function> + 0x1847f3 (0x558f086057f3 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #58: <unknown function> + 0x140699 (0x558f085c1699 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #59: <unknown function> + 0x7df36 (0x558f084fef36 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #60: <unknown function> + 0x8af1b (0x558f0850bf1b in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #61: <unknown function> + 0x1409a0 (0x558f085c19a0 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #62: <unknown function> + 0xfeb84 (0x558f0857fb84 in /home/pawat/anaconda3/envs/pytorch14/bin/python)
# frame #63: _PyEval_EvalCodeWithName + 0x659 (0x558f0860be19 in /home/pawat/anaconda3/envs/pytorch14/bin/python)

# %% [markdown]
# ### Model performance

# %%
model_path = 'model_best.pth.tar'
# calculate outputs for the test data with our best model
output_csv_path = 'pred.csv'
command = ('python pred.py '
           '--img_dir /home/dhwon/data_hdd2/UCLA-protest/img/test/ '
           '--output_csvpath {csv_path} '
           '--model {model} --batch_size 4 --cuda'
           .format(csv_path = output_csv_path, model = model_path))

            
# !{command}

# load prediction
df_pred = pd.read_csv(output_csv_path)
df_pred['imgpath'] = df_pred['imgpath'].apply(os.path.basename)

# load target
test_label_path = '/home/dhwon/data_hdd2/UCLA-protest/annot_test.txt'
df_target = pd.read_csv(test_label_path, delimiter= '\t')

# %% [markdown]
# #### Binary Variables

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
def plot_roc(attr, target, pred):
    """Plot a ROC curve and show the accuracy score and the AUC"""
    fig, ax = plt.subplots()
    auc = roc_auc_score(target, pred)
    acc = accuracy_score(target, (pred >= 0.5).astype(int))
    fpr, tpr, _ = roc_curve(target, pred)
    plt.plot(fpr, tpr, lw = 2, label = attr.title())
    plt.legend(loc = 4, fontsize = 15)
    plt.title(('ROC Curve for {attr} (Accuracy = {acc:.3f}, AUC = {auc:.3f})'
               .format(attr = attr.title(), acc= acc, auc = auc)),
              fontsize = 15)
    plt.xlabel('False Positive Rate', fontsize = 15)
    plt.ylabel('True Positive Rate', fontsize = 15)
    plt.show()
    return fig

# %%
# plot ROC curve for protest
attr = "protest"
target = df_target[attr]
pred = df_pred[attr]
fig = plot_roc(attr, target, pred)
fig.savefig(os.path.join('files', attr+'.png'))
# plot ROC curves for visual attributes
for attr in df_pred.columns[3:]:
    target = df_target[attr]
    pred = df_pred[attr][target != '-']
    target = target[target != '-'].astype(int)
    fig = plot_roc(attr, target, pred)
    fig.savefig(os.path.join('files', attr+'.png'))

# %% [markdown]
# #### Violence

# %%
import scipy.stats as stats
attr = 'violence'
pred = df_pred[df_target['protest'] == 1][attr].tolist()
target = df_target[df_target['protest'] == 1][attr].astype(float).tolist()
fig, ax = plt.subplots()
plt.scatter(target, pred, label = attr.title())
plt.xlim([-.05,1.05])
plt.ylim([-.05,1.05])
plt.xlabel('Annotation', fontsize = 15)
plt.ylabel('Predicton', fontsize = 15)
corr, pval = stats.pearsonr(target, pred)
plt.title(('Scatter Plot for {attr} (Correlation = {corr:.3f})'
            .format(attr = attr.title(), corr= corr)), fontsize = 15)
plt.show()
fig.savefig(os.path.join('files', attr+'.png'))
